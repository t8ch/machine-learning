# %%
# %pylab
import glob
from scipy.ndimage import imread
from scipy.ndimage.interpolation import zoom
from scipy.misc import imresize
import pandas as pd
import seaborn as sns
sns.set_style('white')
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # load and preprocess data

# %%
labels = pd.read_csv('labels.csv')
labels.columns = ['digit', 'label']

# %%
labels.head()
# Out:
#      digit  label
# 0  digit_1      4
# 1  digit_2      2
# 2  digit_3      3
# 3  digit_4      1
# 4  digit_5      2

# %% [markdown]
# **create one-hot-encoding array for later purpose**

# %%
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1392 entries, 0 to 1391
# Data columns (total 2 columns):
# digit    1392 non-null object
# label    1392 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 21.8+ KB

# %%
labels.label.hist()

# %% [markdown]
# the data are not perfectly balanced but chance level would still be <0.2

# %% [markdown]
# *one-hot-encoding*

# %%
dummies = pd.get_dummies(labels, columns = ['label'], )
one_hot_labels =array(dummies.drop('digit', axis = 1))

# %%
image_list = []
# bring in order according to labels.xls
for filename in sorted(glob.glob('BDRW_train/*.jpg'), key=lambda a: int(a.split("_")[-1].split('.')[0]))[1:]: #because digit_0 not in labels
    im=imread(filename)
    image_list.append(array(im))

# %% [markdown]
# plot distribution of image sizes

# %%
shapes = array([x.shape for x in image_list]).T
scatter(shapes[0], shapes[1])

# %%
mean(shapes[:2], 1)
# Out:
# array([ 35.4612069 ,  27.83333333])

# %% [markdown]
# **rescale all images to 35x28 and fill open space with mean of boundary line**

# %%
def resize_and_fill(im, X=35, Y = 28):
    i = argmin(im.shape[:2])
    i = im.shape[0]/float(im.shape[1]) >= 1.25
    if i == 0:
        test_im = imresize(im, (int(im.shape[0]*float(Y)/im.shape[1]) , Y, 3) )
    if i == 1:
        test_im = imresize(im, (X, int(im.shape[1]*float(X)/im.shape[0]), 3) )

    shape_test = array(test_im.shape[:2])
    test_im2 = ones((X, Y ,3))
    if i == 0:
        for k in range(3):
            test_im2[:, :, k] = concatenate((test_im[:,:,k], ones((X-shape_test[0], Y))*mean(test_im[-1,:,k])), 0)

    if i == 1:
        for k in range(3):
            test_im2[:, :, k] = concatenate((test_im[:,:,k], ones((X, Y-shape_test[1]))*mean(test_im[:,-1,k])), 1)
    return test_im2.astype(uint8)

# %%
adjusted_im = array([resize_and_fill(x) for x in image_list])

# %% [markdown]
# **augment data by simple inversion of color channels**

# %%
adjusted_im2 = append(adjusted_im, array([x[:,:,[1,0,2]] for x in adjusted_im]), 0)
one_hot_labels2 = append(one_hot_labels, one_hot_labels, 0)

# %%
fig, ax = subplots(5, 5, figsize = (14, 10))
for x in range(5):
    for y in range(5):
        rn = random_integers(0, len(adjusted_im))
        ax[x,y].imshow(adjusted_im[rn])
        ax[x,y].set_title(labels.label.iloc[rn])
show()
# Out:
# /home/herfurtht/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: DeprecationWarning: This function is deprecated. Please call randint(0, 1392 + 1) instead

# %% [markdown]
# # Build CNN in Keras

# %%
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import keras.backend as K

earlyStopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=2, verbose=0, mode='auto')
# Out:
# Using TensorFlow backend.

# %%
K.clear_session()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

model = Sequential()
model.add(Dropout(0.3, input_shape=((35, 28, 3))))
model.add(Conv2D(32, (3, 3), input_shape=(35, 28, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))

# %%
model.add(Flatten())  #3D feature maps to 1D feature vectors
model.add(Dense(64, kernel_regularizer= 'l2'))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(10, kernel_regularizer= 'l2'))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'],
             callbacks = [earlyStopping])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_1 (Dropout)          (None, 35, 28, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 33, 26, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 33, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 11, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 11, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 5, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 3, 64)          18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 5, 3, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                61504
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 90,794.0
# Trainable params: 90,794.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(adjusted_im2, one_hot_labels2, test_size = .1)

# %%
# %%time

hist = model.fit(X_train, y_train, epochs = 150, batch_size = 64, verbose = True)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 5.96 µs
# Epoch 1/150
#  128/2505 [>.............................] - ETA: 3s - loss: 15.5770 - acc: 0.0859
# /home/herfurtht/miniconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:2094: UserWarning: Expected no kwargs, you passed 1
# kwargs passed to function are ignored with Tensorflow backend
#   warnings.warn('\n'.join(msg))
# 2505/2505 [==============================] - 2s - loss: 15.0080 - acc: 0.1142
# Epoch 2/150
# 2505/2505 [==============================] - 2s - loss: 13.9373 - acc: 0.1601
# Epoch 3/150
# 2505/2505 [==============================] - 2s - loss: 6.4718 - acc: 0.1681
# Epoch 4/150
# 2505/2505 [==============================] - 2s - loss: 2.5414 - acc: 0.2116
# Epoch 5/150
# 2505/2505 [==============================] - 2s - loss: 2.1806 - acc: 0.3082
# Epoch 6/150
# 2505/2505 [==============================] - 2s - loss: 1.7969 - acc: 0.4415
# Epoch 7/150
# 2505/2505 [==============================] - 2s - loss: 1.4332 - acc: 0.5573
# Epoch 8/150
# 2505/2505 [==============================] - 2s - loss: 1.1620 - acc: 0.6511
# Epoch 9/150
# 2505/2505 [==============================] - 3s - loss: 0.9732 - acc: 0.7198
# Epoch 10/150
# 2505/2505 [==============================] - 3s - loss: 0.8445 - acc: 0.7693
# Epoch 11/150
# 2505/2505 [==============================] - 3s - loss: 0.7388 - acc: 0.8028
# Epoch 12/150
# 2505/2505 [==============================] - 3s - loss: 0.6838 - acc: 0.8311
# Epoch 13/150
# 2505/2505 [==============================] - 3s - loss: 0.6276 - acc: 0.8443
# Epoch 14/150
# 2505/2505 [==============================] - 3s - loss: 0.5599 - acc: 0.8611
# Epoch 15/150
# 2505/2505 [==============================] - 3s - loss: 0.5804 - acc: 0.8499
# Epoch 16/150
# 2505/2505 [==============================] - 3s - loss: 0.4867 - acc: 0.8874
# Epoch 17/150
# 2505/2505 [==============================] - 3s - loss: 0.4852 - acc: 0.8866
# Epoch 18/150
# 2505/2505 [==============================] - 3s - loss: 0.4730 - acc: 0.8962
# Epoch 19/150
# 2505/2505 [==============================] - 3s - loss: 0.4192 - acc: 0.9094
# Epoch 20/150
# 2505/2505 [==============================] - 3s - loss: 0.4378 - acc: 0.8990
# Epoch 21/150
# 2505/2505 [==============================] - 3s - loss: 0.4087 - acc: 0.9106
# Epoch 22/150
# 2505/2505 [==============================] - 3s - loss: 0.3904 - acc: 0.9146
# Epoch 23/150
# 2505/2505 [==============================] - 3s - loss: 0.3743 - acc: 0.9186
# Epoch 24/150
# 2505/2505 [==============================] - 3s - loss: 0.3489 - acc: 0.9281
# Epoch 25/150
# 2505/2505 [==============================] - 3s - loss: 0.3561 - acc: 0.9285
# Epoch 26/150
# 2505/2505 [==============================] - 3s - loss: 0.3261 - acc: 0.9393
# Epoch 27/150
# 2505/2505 [==============================] - 3s - loss: 0.3454 - acc: 0.9297
# Epoch 28/150
# 2505/2505 [==============================] - 3s - loss: 0.3218 - acc: 0.9349
# Epoch 29/150
# 2505/2505 [==============================] - 3s - loss: 0.3338 - acc: 0.9353
# Epoch 30/150
# 2505/2505 [==============================] - 3s - loss: 0.3341 - acc: 0.9381
# Epoch 31/150
# 2505/2505 [==============================] - 3s - loss: 0.3051 - acc: 0.9421
# Epoch 32/150
# 2505/2505 [==============================] - 3s - loss: 0.3085 - acc: 0.9373
# Epoch 33/150
# 2505/2505 [==============================] - 3s - loss: 0.2961 - acc: 0.9417
# Epoch 34/150
# 2505/2505 [==============================] - 3s - loss: 0.2855 - acc: 0.9445
# Epoch 35/150
#  - ETA: 3s - loss: 0.2943 - acc: 0.9453
# Epoch 36/150
# 2505/2505 [==============================] - 3s - loss: 0.2641 - acc: 0.9505
# Epoch 37/150
# 2505/2505 [==============================] - 4s - loss: 0.2729 - acc: 0.9505
# Epoch 38/150
# 2505/2505 [==============================] - 3s - loss: 0.2567 - acc: 0.9481
# Epoch 39/150
# 2505/2505 [==============================] - 4s - loss: 0.2651 - acc: 0.9497
# Epoch 40/150
#  - ETA: 2s - loss: 0.2420 - acc: 0.9560
# Epoch 41/150
#  - ETA: 3s - loss: 0.2686 - acc: 0.9531
# Epoch 42/150
# 2505/2505 [==============================] - 4s - loss: 0.2655 - acc: 0.9509
# Epoch 43/150
# 2505/2505 [==============================] - 4s - loss: 0.2320 - acc: 0.9537
# Epoch 44/150
# 2505/2505 [==============================] - 4s - loss: 0.2346 - acc: 0.9561
# Epoch 45/150
# 2505/2505 [==============================] - 4s - loss: 0.2253 - acc: 0.9553
# Epoch 46/150
# 2505/2505 [==============================] - 4s - loss: 0.2292 - acc: 0.9549
# Epoch 47/150
# 2505/2505 [==============================] - 4s - loss: 0.2383 - acc: 0.9553
# Epoch 48/150
#  - ETA: 2s - loss: 0.2020 - acc: 0.9698
# Epoch 49/150
#  - ETA: 1s - loss: 0.2083 - acc: 0.9665
# Epoch 50/150
# 2505/2505 [==============================] - 4s - loss: 0.2347 - acc: 0.9549
# Epoch 51/150
# 2505/2505 [==============================] - 4s - loss: 0.2197 - acc: 0.9617
# Epoch 52/150
# 2505/2505 [==============================] - 4s - loss: 0.2093 - acc: 0.9649
# Epoch 53/150
# 2505/2505 [==============================] - 4s - loss: 0.2005 - acc: 0.9669
# Epoch 54/150
# 2505/2505 [==============================] - 4s - loss: 0.2123 - acc: 0.9609
# Epoch 55/150
# 2505/2505 [==============================] - 4s - loss: 0.1993 - acc: 0.9661
# Epoch 56/150
# 2505/2505 [==============================] - 4s - loss: 0.1942 - acc: 0.9689
# Epoch 57/150
# 2505/2505 [==============================] - 4s - loss: 0.1983 - acc: 0.9677
# Epoch 58/150
# 2505/2505 [==============================] - 4s - loss: 0.2074 - acc: 0.9641
# Epoch 124/150
#  - ETA: 2s - loss: 0.0734 - acc: 0.9932
# Epoch 125/150
# 2505/2505 [==============================] - 4s - loss: 0.1088 - acc: 0.9828
# Epoch 126/150
# 2505/2505 [==============================] - 3s - loss: 0.1210 - acc: 0.9788
# Epoch 127/150
# 2505/2505 [==============================] - 3s - loss: 0.1199 - acc: 0.9776
# Epoch 128/150
# 2505/2505 [==============================] - 3s - loss: 0.1225 - acc: 0.9800
# Epoch 129/150
# 2505/2505 [==============================] - 3s - loss: 0.1325 - acc: 0.9752
# Epoch 130/150
# 2505/2505 [==============================] - 4s - loss: 0.1092 - acc: 0.9804
# Epoch 131/150
#  - ETA: 3s - loss: 0.0998 - acc: 0.9922
# Epoch 132/150
# 2505/2505 [==============================] - 3s - loss: 0.1056 - acc: 0.9820
# Epoch 133/150
#  - ETA: 0s - loss: 0.0974 - acc: 0.9868
# Epoch 134/150
# 2505/2505 [==============================] - 4s - loss: 0.1102 - acc: 0.9804
# Epoch 135/150
# 2505/2505 [==============================] - 4s - loss: 0.1243 - acc: 0.9780
# Epoch 136/150
# 2505/2505 [==============================] - 4s - loss: 0.1330 - acc: 0.9804
# Epoch 137/150
# 2505/2505 [==============================] - 3s - loss: 0.1014 - acc: 0.9800
# Epoch 138/150
#  - ETA: 3s - loss: 0.1752 - acc: 0.9844
# Epoch 139/150
# 2505/2505 [==============================] - 4s - loss: 0.1080 - acc: 0.9820
# Epoch 140/150
# 2505/2505 [==============================] - 3s - loss: 0.1214 - acc: 0.9812
# Epoch 141/150
# 2505/2505 [==============================] - 4s - loss: 0.1133 - acc: 0.9816
# Epoch 142/150
#  - ETA: 2s - loss: 0.1001 - acc: 0.9835
# Epoch 143/150
#  - ETA: 3s - loss: 0.0586 - acc: 0.9955
# Epoch 144/150
# 2505/2505 [==============================] - 4s - loss: 0.1122 - acc: 0.9824
# Epoch 145/150
# 2505/2505 [==============================] - 4s - loss: 0.1012 - acc: 0.9852
# Epoch 146/150
# 2505/2505 [==============================] - 5s - loss: 0.1180 - acc: 0.9800
# Epoch 147/150
# 2505/2505 [==============================] - 5s - loss: 0.0885 - acc: 0.9896
# Epoch 148/150
# 2505/2505 [==============================] - 5s - loss: 0.1174 - acc: 0.9792
# Epoch 149/150
# 2505/2505 [==============================] - 5s - loss: 0.1033 - acc: 0.9780
# Epoch 150/150
# 2505/2505 [==============================] - 5s - loss: 0.1033 - acc: 0.9820
# 224/279 [=======================>......] - ETA: 0s
# [0.08265043106130375, 0.99641577060931896]

# %%
figure()
xlabel('epochs')
plot(hist.history['loss'])
ylabel('loss')
legend(['loss'])
twinx(gca())
plot(hist.history['acc'], 'r')
ylabel('accuracy')
legend(['acc'])
show()

# %%
print('loss, accuracy = ', model.evaluate(X_test, y_test))
# Out:
# 279/279 [==============================] - 0s
# ('loss, accuracy = ', [0.08265043106130375, 0.99641577060931896])

# %% [markdown]
# we can reach a very high accuracy here. this was not possible without using the pseudo-augmented data obtained from color inversion
