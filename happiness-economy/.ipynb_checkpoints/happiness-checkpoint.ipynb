# %% [markdown]
# # Correlates of Happiness
# **here, I use the dataset "65 world indexes" to look for predictors of the happiness score of the "world happiness report 2015"**

# %% [markdown]
# ## import and preprocess data

# %%
# %pylab
import pandas as pd
import seaborn as sns
sns.set_style('white')
from scipy.cluster.hierarchy import dendrogram, fcluster
# %matplotlib inline
hap = pd.read_csv("2015.csv") #world happiness report 2015
world = pd.read_csv("65-world-indices-gathered.csv") #65 world indexes
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
hap.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
world.head()
# Out:
#             Id  Human Development Index HDI-2014  Gini coefficient 2005-2013  \
# 0       Norway                          0.943877                       26.83
# 1    Australia                          0.934958                       34.01
# 2  Switzerland                          0.929613                       32.35
# 3      Denmark                          0.923328                       26.88
# 4  Netherlands                          0.921794                       28.87
#
#    Adolescent birth rate 15-19 per 100k 20102015  \
# 0                                          7.834
# 1                                         12.059
# 2                                          1.900
# 3                                          5.101
# 4                                          6.165
#
#    Birth registration funder age 5 2005-2013  \
# 0                                      100.0
# 1                                      100.0
# 2                                      100.0
# 3                                      100.0
# 4                                      100.0
#
#    Carbon dioxide emissionsAverage annual growth  \
# 0                                       0.778925
# 1                                       1.090351
# 2                                      -1.101254
# 3                                      -1.767733
# 4                                      -0.252734
#
#    Carbon dioxide emissions per capita 2011 Tones  \
# 0                                        9.192879
# 1                                       16.519210
# 2                                        4.625230
# 3                                        7.248329
# 4                                       10.064490
#
#    Change forest percentable 1900 to 2012  Change mobile usage 2009 2014  \
# 0                               11.914567                           5.22
# 1                               -4.561812                          30.27
# 2                                8.567416                          16.72
# 3                               23.029974                           1.83
# 4                                5.922602                          -4.31
#
#    Consumer price index 2013                 ...                   \
# 0                 104.194175                 ...
# 1                 107.789440                 ...
# 2                  99.317229                 ...
# 3                 106.057718                 ...
# 4                 107.474154                 ...
#
#    Renewable sources percentage of total 2012  \
# 0                                   47.752676
# 1                                    4.632202
# 2                                   49.659398
# 3                                   26.767245
# 4                                    6.671366
#
#    Research and development expenditure  2005-2012  Secondary 2008-2014  \
# 0                                          1.65474            111.06130
# 1                                          2.38562            135.53543
# 2                                          2.87046             96.30638
# 3                                          2.98416            124.65927
# 4                                          2.15676            129.91277
#
#    Share of seats in parliament percentage held by womand 2014  \
# 0                                          39.644970
# 1                                          30.530973
# 2                                          28.455285
# 3                                          37.988827
# 4                                          36.888889
#
#    Stock of immigrants percentage of population 2013  \
# 0                                          13.772622
# 1                                          27.711793
# 2                                          28.906998
# 3                                           9.909512
# 4                                          11.724418
#
#    Taxes on income profit and capital gain 205 2013  Tertiary -2008-2014  \
# 0                                         31.798391             74.10112
# 1                                         65.333748             86.33409
# 2                                         22.673299             55.56190
# 3                                         39.677938             79.59763
# 4                                         23.533104             77.34356
#
#    Total tax revenue of GDP 2005-2013  Tuberculosis rate per thousands 2012  \
# 0                           27.288097                                  0.14
# 1                           21.361426                                  0.19
# 2                            9.759124                                  0.22
# 3                           33.395651                                  0.40
# 4                           19.724059                                  0.17
#
#    Under-five Mortality 2013 thousands
# 0                                  2.8
# 1                                  4.0
# 2                                  4.2
# 3                                  3.5
# 4                                  4.0
#
# [5 rows x 66 columns]

# %%
world.columns = concatenate([[hap.columns[0]], world.columns[1:]]) #equalize country first column

# %%
hap.shape, \
world.shape
# Out:
# ((158, 12), (188, 66))

# %% [markdown]
# find differences in country spelling and correct for them

# %%
print set(hap['Country']).symmetric_difference(world['Country'])
#congo, dom rer. congo, hongkong, Palestine,
# Out:
# set(['East Timor', 'Republic of the Congo', 'Palestine', 'Cape Verde', 'Congo (Kinshasa)', 'S\xc3\xa3o Tom\xc3\xa9 and Pr\xc3\xadncipe', 'Ivory Coast', 'Bahamas', 'Samoa', "C\xc3\xb4te d'Ivoire", 'Congo (Brazzaville)', 'Saint Vincent and the Grenadines', 'Eritrea', 'Solomon Islands', 'Saint Lucia', 'Vanuatu', 'Saint Kitts and Nevis', 'Tonga', 'Fiji', 'Liechtenstein', 'Guyana', 'Andorra', 'Palau', 'Brunei', 'Belize', 'Hong Kong\xc2\xa0', 'Micronesia', 'Guinea-Bissau', 'Kiribati', 'Grenada', 'Seychelles', 'Kosovo', 'Hong Kong', 'Equatorial Guinea', 'Antigua and Barbuda', 'Dominica', 'North Cyprus', 'Taiwan', 'Barbados', 'Palestinian Territories', 'Democratic Republic of the Congo', 'Maldives', 'Papua New Guinea', 'Somaliland region', 'Gambia', 'South Sudan', 'Cuba', 'Namibia'])

# %%
old_names, new_names = (['Congo (Brazzaville)', 'Congo (Kinshasa)', 'Hong Kong\xc2\xa0', 'Palestinian Territories'],
                         ['Republic of the Congo',
                          'Democratic Republic of the Congo',
                          'Hong Kong',
                          'Palestine'])

# %% [markdown]
# adapt country names, 153 countries overlap in both datasets

# %%
hap['Country'].replace(old_names, new_names, inplace = True)
world['Country'].replace(old_names, new_names, inplace = True)

# %%
len(set(hap['Country']).intersection(world['Country'])), \
len(set(hap['Country']).symmetric_difference(world['Country']))
# Out:
# (153, 40)

# %% [markdown]
# merge data sets and remove features from happiness report

# %%
merged = hap[['Country','Happiness Score']].merge(world, how = 'inner', on = 'Country')

# %% [markdown]
# 'thinning' data (discard regional information, (arguably) redundant features and features from happiness report)

# %%
merged.drop(['Country', u'Gross domestic product GDP 2013', 'Infant Mortality 2013 per thousands', 'Gross national income GNI per capita - 2011  Dollars', 'Birth registration funder age 5 2005-2013', 'Pre-primary 2008-2014', u'International inbound tourists thausands 2013', u'International student mobility of total tetiary enrolvemnt 2013', ], axis = 1, inplace = True)

# %% [markdown]
# ## feature correlations

# %%
corr_matrix = merged.corr()

# %% [markdown]
# **raw correlation matrix**

# %%
figure(figsize = (15, 15))
sns.heatmap(corr_matrix, xticklabels= False)

# %% [markdown]
# **clusters of correlated features** (absolute value: sign does not matter)

# %%
figure(figsize = (16, 16))
#sns.heatmap(merged.corr())
cg = sns.clustermap(merged.corr().applymap(abs), xticklabels = True, yticklabels = False)
# Out:
# /home/herfurtht/miniconda2/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#figure(figsize = (9, 6))
#a = dendrogram(cg.dendrogram_col.linkage, labels = merged.columns, color_threshold = 2, leaf_font_size= 10)
fc = fcluster(cg.dendrogram_col.linkage, 2, criterion = 'distance')

# %% [markdown]
# we find a cluster of highly correlated features among which is the 'Happiness Score'. we expect these features to be predictors for happiness but at the same time to be interdependent.
# these features are part of the cluster:

# %%
pd.Series(data = merged.columns[fc == 1])
# Out:
# 0                                       Happiness Score
# 1                      Human Development Index HDI-2014
# 2         Adolescent birth rate 15-19 per 100k 20102015
# 3        Carbon dioxide emissions per capita 2011 Tones
# 4                         Change mobile usage 2009 2014
# 5     Domestic credit provided by financial sector 2013
# 6             Domestic food price level 2009 2014 index
# 7                    Electrification rate or population
# 8                   Expected years of schooling - Years
# 9                 Fossil fuels percentage of total 2012
# 10                         Gender Inequality Index 2014
# 11                  Gross domestic product GDP percapta
# 12         Internet users percentage of population 2014
# 13                      Life expectancy at birth- years
# 14    Maternal mortality ratio deaths per 100 live b...
# 15                      Mean years of schooling - Years
# 16       Mobile phone subscriptions per 100 people 2014
# 17                            Physicians per 10k people
# 18    Population with at least some secondary educat...
# 19                Primary school dropout rate 2008-2014
# 20    Pupil-teacher ratio primary school pupils per ...
# 21           Renewable sources percentage of total 2012
# 22      Research and development expenditure  2005-2012
# 23                                  Secondary 2008-2014
# 24                                  Tertiary -2008-2014
# 25                 Tuberculosis rate per thousands 2012
# 26                  Under-five Mortality 2013 thousands
# dtype: object

# %% [markdown]
# ## correlates of 'Happiness Score'
# **let's extract the strongest correlations with happiness (> 0.2, irrespective of the sign)** <br>

# %%
hap_corr = pd.DataFrame(merged.corr()[abs(merged.corr()['Happiness Score']) > .2]['Happiness Score'])
hap_corr.drop('Happiness Score', axis = 0, inplace = True)
hap_corr.columns = ['Corr. with happiness']
hap_corr.sort(columns = 'Corr. with happiness', axis = 0, ascending = False)
# Out:
# /home/herfurtht/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                                                     Corr. with happiness
# Human Development Index HDI-2014                                0.795179
# Internet users percentage of population 2014                    0.779305
# Life expectancy at birth- years                                 0.727921
# Secondary 2008-2014                                             0.720465
# Expected years of schooling - Years                             0.706805
# Gross domestic product GDP percapta                             0.688362
# Mean years of schooling - Years                                 0.686146
# Electrification rate or population                              0.659038
# Tertiary -2008-2014                                             0.640498
# Population with at least some secondary educati...              0.625360
# Physicians per 10k people                                       0.584003
# Research and development expenditure  2005-2012                 0.557784
# Carbon dioxide emissions per capita 2011 Tones                  0.507946
# Mobile phone subscriptions per 100 people 2014                  0.495252
# Domestic credit provided by financial sector 2013               0.495242
# Stock of immigrants percentage of population 2013               0.406598
# Net migration rate per 1k people 2010-2015                      0.324899
# Public health expenditure percentage of GDP 2013                0.319927
# Change forest percentable 1900 to 2012                          0.309646
# General government final consumption expenditur...              0.295836
# Public expenditure on education Percentange GDP                 0.288424
# Fossil fuels percentage of total 2012                           0.278395
# Share of seats in parliament percentage held by...              0.258148
# Prison population per 100k people                               0.257456
# Consumer price index 2013                                      -0.203803
# Natural resource depletion                                     -0.224644
# Gini coefficient 2005-2013                                     -0.235643
# Remittances inflows percentual GDP 2013                        -0.279085
# Domestic food price level 2009-2014 volitility ...             -0.286370
# Population affected by natural desasters averag...             -0.298752
# Renewable sources percentage of total 2012                     -0.397324
# Population living on degraded land Percentage 2010             -0.413936
# Change mobile usage 2009 2014                                  -0.441901
# Tuberculosis rate per thousands 2012                           -0.442942
# Adolescent birth rate 15-19 per 100k 20102015                  -0.513469
# Primary school dropout rate 2008-2014                          -0.589976
# Maternal mortality ratio deaths per 100 live bi...             -0.618290
# Under-five Mortality 2013 thousands                            -0.645684
# Gender Inequality Index 2014                                   -0.660578
# Pupil-teacher ratio primary school pupils per t...             -0.675176
# Domestic food price level 2009 2014 index                      -0.733781

# %%
hap_corr_best = hap_corr.apply(abs).sort(columns = 'Corr. with happiness', axis = 0, ascending = False)
# Out:
# /home/herfurtht/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %% [markdown]
# **plot correlation matrix of 20 most correlated features with happiness**
# again, they are highly correlated among themselfes

# %%
figure(figsize = (12,10))
sns.heatmap(corr_matrix.apply(abs).loc[hap_corr_best[:20].index,hap_corr_best[:20].index], annot= True)

# %% [markdown]
# ## linear regression for happiness
# **how well can the most correlated features "predict" happiness (despite being highly interdependent)?**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# plot regression score against number of most important features included

# %%
hap_corr_best = hap_corr.apply(abs).sort(columns = 'Corr. with happiness', axis = 0, ascending = False)
figure(figsize = (8,6))
scores = zeros((35, len(hap_corr_best.index)-1))
for i in range(35):
    for k in range(1,len(hap_corr_best.index)):
        X, y = array(merged[hap_corr_best.index[:k]]), array(merged['Happiness Score'])
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)
        linReg = LinearRegression(normalize = True)
        linReg.fit(X_train,y_train)
        sc = linReg.score(X_test, y_test)
        scores[i][k-1] = sc
sns.tsplot(time = range(1,len(hap_corr_best.index)), data = scores)
xlabel("# most important features")
ylabel("$R^2$ score of lin. regression")
show()
# Out:
# /home/herfurtht/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %% [markdown]
# the $R^2$ score never beats 0.65 and is usually around 0.55-0.66 which corresponds to a coeff of corr ~0.8. this is equaivalent to the coeff of corr of the highest corelated features (see above). hence, because all predictive features are interdependendent they don't contribute additional information about happiness.

# %% [markdown]
# ## going deeper

# %% [markdown]
# **can we extract nonlinear dependencies or hidden composite variables?** <br>
# let's try a simple ANN with one hidden layer (may take some time depending in computing power)

# %%
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from keras import optimizers

def coeff_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

stopper = EarlyStopping(monitor='loss', min_delta=0, patience = 8, verbose= 0, mode='auto')
MinMax = MinMaxScaler()

# %%
# %%time 

hap_corr_best = hap_corr.apply(abs).sort(columns = 'Corr. with happiness', axis = 0, ascending = False)
figure(figsize = (8,6))
scores2 = zeros((3, len(hap_corr_best.index)-1))
for k in range(1,len(hap_corr_best.index)):
    K.clear_session()
    X, y = array(merged[hap_corr_best.index[:k]]), array(merged['Happiness Score'])
    X = MinMax.fit_transform(X)
    for i in range(3):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)
        model = Sequential()
        model.add(Dense(2*k, input_dim = k, activation = 'relu'))
        model.add(Dense(1))

        model.compile(optimizer= 'rmsprop',
                      loss='mse', metrics = [coeff_determination])

        model.fit(X_train, y_train, epochs = 500, batch_size = 32, verbose = 0, callbacks= [stopper])
        sc = model.evaluate(X_test, y_test, verbose = 0)
        scores2[i][k-1]= sc[1]
sns.tsplot(time = range(1,len(hap_corr_best.index)), data = scores2)
xlabel("# most important features")
ylabel("$R^2$ score of lin. regression")
show()
#model.summary()
# Out:
# /home/herfurtht/miniconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
# CPU times: user 4min 9s, sys: 14.4 s, total: 4min 23s
# Wall time: 2min 55s

# %% [markdown]
# comparison of lin. regression and ANN

# %%
figure(figsize = (7,5))
sns.tsplot(time = range(1,len(hap_corr_best.index)), data = scores2, err_style = "unit_traces", condition = 'ANN')
sns.tsplot(time = range(1,len(hap_corr_best.index)), data = scores, color = 'r', condition = 'linear')
ylim([0,1])
show()

# %% [markdown]
# results of lin. reg. and ANN seem to be similar in terms of $R^2$ score. no higher order dependence could be found. <br>
# results for ANN are vary variable. they did not significantly change for 2 hidden layers and different optimizers/activations. <br>
# ** of course, the result does not imply that no better prediction of happiness is possible. yet, it seem not straight forward. ** <br>
